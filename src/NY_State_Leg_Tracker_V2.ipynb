# %%
import requests
import json
import pandas as pd
from datetime import datetime

# %%
# Replace with your actual API key
api_key = "XLC9cIQDZOgmCiMCT43D1umf6VeOFuGU"

# Base URL for the API
base_url = "https://legislation.nysenate.gov/api/3/bills/"

# mapping columns to city tracker
column_mappings = {
    "Last Updated": None,  # date tracker is exported
    "Session": "session", #session that bill was introduced
    "Chamber": "billType_desc", #chamber that bill was introduced in
    "Bill Number": "basePrintNo", #bill
    "Date Introed": "publishedDateTime",  # this date will be reformatted
    "Automated Status": "status_statusDesc", #status of the bill
    "Sponsor": "sponsor_member_fullName",
    "Co Sponsor Count": "amendments_items_coSponsors_size",  # result.amendments.items..coSponsors.size
    "Co Sponsor Count Change": None,  # 
    "Bill Last Changed": "status_actionDate", 
    "Summary": "summary",
    "Committee": "status_committeeName", #committee name
    "Co Sponsors": None,  # number of co-sponsors. if none should be 0
    "Notes": None,  # 
    "Laws Impacted": "amendments_items_relatedLaws_items_AMEND_items",  #result.amendments.items..relatedLaws.items.AMEND.items
    "Bill Link": None, # add the link to the bill url
    "Priority Level": None  #copying from city tracker
}
# ADD a filter for state committee

# %%
def fetch_bills_by_year(api_key, session_year, committee_filter=None):
    """
    Fetch all the bills for a given session year from the NY Senate API,
    with an optional filter for committee names applied later in the logic.
    """
    page = 1
    all_bills = []
    
    while True:
        url = f"{base_url}{session_year}?key={api_key}&page={page}"
        
        try:
            response = requests.get(url)

            # Check if the request was successful (status code 200)
            if response.status_code == 200:
                bill_data = response.json()

                if bill_data.get("result") and bill_data["result"].get("items"):
                    bills = bill_data["result"]["items"]
                    print(f"Fetched {len(bills)} bills from page {page}.")

                    # Add the fetched bills to the list
                    all_bills.extend(bills)

                    # Check if there are more pages
                    if len(bills) < 50:  # Assuming the page size is 50
                        break  # No more bills to fetch
                    page += 1  # Fetch the next page
                else:
                    print(f"No bills found for session year {session_year}.")
                    break
            else:
                print(f"Failed to retrieve bills. Status code: {response.status_code}")
                print(f"Response: {response.text}")
                break
        except requests.exceptions.RequestException as e:
            print(f"Error fetching data: {e}")
            break

    # Apply committee filter after fetching all the bills
    if committee_filter:
        all_bills = [bill for bill in all_bills if 
                     (bill.get("status", {}).get("committeeName") in committee_filter) or
                     any(milestone.get("committeeName") in committee_filter for milestone in bill.get("milestones", {}).get("items", []))]

    return all_bills

# %%
def flatten_json(nested_json, parent_key='', sep='_'):
    """
    Flatten a nested JSON into a flat dictionary.
    """
    items = []
    for k, v in nested_json.items():
        new_key = f"{parent_key}{sep}{k}" if parent_key else k
        if isinstance(v, dict):
            items.extend(flatten_json(v, new_key, sep=sep).items())
        elif isinstance(v, list):
            for i, item in enumerate(v):
                items.extend(flatten_json(item, f"{new_key}_{i}", sep=sep).items())
        else:
            items.append((new_key, v))
    return dict(items)

# %%
def get_column_data(item, column_mappings):
    """
    Create a row of data based on the column mappings.
    """
    row_data = {}

    for column, key in column_mappings.items():
        if key:
            # Check if the key exists in the flattened JSON data and add it to the row
            value = item.get(key, "")

            # If the column is 'Date Introed', format it as 'YYYY-MM-DD'
            if column == "Date Introed" and value:
                try:
                    # Convert to date format (YYYY-MM-DD)
                    formatted_date = datetime.fromisoformat(value).date()
                    row_data[column] = formatted_date
                except ValueError:
                    row_data[column] = value  # If it can't be converted, leave the original value
            else:
                row_data[column] = value
        else:
            # Handle empty columns that need to be calculated or filled manually
            if column == "Last Updated":
                row_data[column] = datetime.now().strftime("%Y-%m-%d")  # Set today's date for 'Last Updated'
            else:
                row_data[column] = ""

    return row_data

# %%
def export_to_excel(bill_data, filename="NY_Senate_bills_data"):
    """
    Export the flattened bill data into an Excel file.
    """
    flattened_data = []

    for item in bill_data:
        flattened_item = flatten_json(item)
        row_data = get_column_data(flattened_item, column_mappings)
        flattened_data.append(row_data)

    # Create a DataFrame
    df = pd.DataFrame(flattened_data)

    # Export the data to Excel
    if not df.empty:
        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
        filename = f"{filename}_{timestamp}.xlsx"
        df.to_excel(filename, index=False)
        print(f"Data exported to {filename}")
    else:
        print("No data to export to Excel.")

# %%
def main():
    session_year = 2025  # Specify the session year (e.g., 2023)
    
    # Define a list of committees to filter by (e.g., 'Education', 'Judiciary')
    committee_filter = ['Elections'] 

    bill_data = fetch_bills_by_year(api_key, session_year, committee_filter)

    if bill_data:
        # Export the filtered and flattened data to Excel
        export_to_excel(bill_data)
    else:
        print("No data retrieved from the API.")

if __name__ == "__main__":
    main()
# Out:
# Fetched 50 bills from page 1.
# Fetched 50 bills from page 2.
# Fetched 50 bills from page 3.
# Fetched 50 bills from page 4.
# Fetched 50 bills from page 5.
# Fetched 50 bills from page 6.
# Fetched 50 bills from page 7.
# Fetched 50 bills from page 8.
# Fetched 50 bills from page 9.
# Fetched 50 bills from page 10.
# Fetched 50 bills from page 11.
# Fetched 50 bills from page 12.
# Fetched 50 bills from page 13.
# Fetched 50 bills from page 14.
# Fetched 50 bills from page 15.
# Fetched 50 bills from page 16.
# Fetched 50 bills from page 17.
# Fetched 50 bills from page 18.
# Fetched 50 bills from page 19.
# Fetched 50 bills from page 20.
# Fetched 50 bills from page 21.
# Fetched 50 bills from page 22.
# Fetched 50 bills from page 23.
# Fetched 50 bills from page 24.
# Fetched 50 bills from page 25.
# Fetched 50 bills from page 26.
# Fetched 50 bills from page 27.
# Fetched 50 bills from page 28.
# Fetched 50 bills from page 29.
# Fetched 50 bills from page 30.
# Fetched 50 bills from page 31.
# Fetched 50 bills from page 32.
# Fetched 50 bills from page 33.
# Fetched 50 bills from page 34.
# Fetched 50 bills from page 35.
# Fetched 50 bills from page 36.
# Fetched 50 bills from page 37.
# Fetched 50 bills from page 38.
# Fetched 50 bills from page 39.
# Fetched 50 bills from page 40.
# Fetched 50 bills from page 41.
# Fetched 50 bills from page 42.
# Fetched 50 bills from page 43.
# Fetched 50 bills from page 44.
# Fetched 50 bills from page 45.
# Fetched 50 bills from page 46.
# Fetched 50 bills from page 47.
# Fetched 50 bills from page 48.
# Fetched 50 bills from page 49.
# Fetched 50 bills from page 50.
# Fetched 50 bills from page 51.
# Fetched 50 bills from page 52.
# Fetched 50 bills from page 53.
# Fetched 50 bills from page 54.
# Fetched 50 bills from page 55.
# Fetched 50 bills from page 56.
# Fetched 50 bills from page 57.
# Fetched 50 bills from page 58.
# Fetched 50 bills from page 59.
# Fetched 50 bills from page 60.
# Fetched 50 bills from page 61.
# Fetched 50 bills from page 62.
# Fetched 50 bills from page 63.
# Fetched 50 bills from page 64.
# Fetched 50 bills from page 65.
# Fetched 50 bills from page 66.
# Fetched 50 bills from page 67.
# Fetched 50 bills from page 68.
# Fetched 50 bills from page 69.
# Fetched 50 bills from page 70.
# Fetched 50 bills from page 71.
# Fetched 50 bills from page 72.
# Fetched 50 bills from page 73.
# Fetched 50 bills from page 74.
# Fetched 50 bills from page 75.
# Fetched 50 bills from page 76.
# Fetched 50 bills from page 77.
# Fetched 50 bills from page 78.
# Fetched 50 bills from page 79.
# Fetched 50 bills from page 80.
# Fetched 50 bills from page 81.
# Fetched 50 bills from page 82.
# Fetched 50 bills from page 83.
# Fetched 50 bills from page 84.
# Fetched 50 bills from page 85.
# Fetched 50 bills from page 86.
# Fetched 50 bills from page 87.
# Fetched 50 bills from page 88.
# Fetched 50 bills from page 89.
# Fetched 50 bills from page 90.
# Fetched 50 bills from page 91.
# Fetched 50 bills from page 92.
# Fetched 50 bills from page 93.
# Fetched 50 bills from page 94.
# Fetched 50 bills from page 95.
# Fetched 50 bills from page 96.
# Fetched 50 bills from page 97.
# Fetched 50 bills from page 98.
# Fetched 50 bills from page 99.
# Fetched 50 bills from page 100.
# Fetched 50 bills from page 101.
# Fetched 50 bills from page 102.
# Fetched 50 bills from page 103.
# Fetched 50 bills from page 104.
# Fetched 50 bills from page 105.
# Fetched 50 bills from page 106.
# Fetched 50 bills from page 107.
# Fetched 50 bills from page 108.
# Fetched 50 bills from page 109.
# Fetched 50 bills from page 110.
# Fetched 50 bills from page 111.
# Fetched 50 bills from page 112.
# Fetched 50 bills from page 113.
# Fetched 50 bills from page 114.
# Fetched 50 bills from page 115.
# Fetched 50 bills from page 116.
# Fetched 50 bills from page 117.
# Fetched 50 bills from page 118.
# Fetched 50 bills from page 119.
# Fetched 50 bills from page 120.
# Fetched 50 bills from page 121.
# Fetched 50 bills from page 122.
# Fetched 50 bills from page 123.
# Fetched 50 bills from page 124.
# Fetched 50 bills from page 125.
# Fetched 50 bills from page 126.
# Fetched 50 bills from page 127.
# Fetched 50 bills from page 128.
# Fetched 50 bills from page 129.
# Fetched 50 bills from page 130.
# Fetched 50 bills from page 131.
# Fetched 50 bills from page 132.
# Fetched 50 bills from page 133.
# Fetched 50 bills from page 134.
# Fetched 50 bills from page 135.
# Fetched 50 bills from page 136.
# Fetched 50 bills from page 137.
# Fetched 50 bills from page 138.
# Fetched 50 bills from page 139.
# Fetched 50 bills from page 140.
# Fetched 50 bills from page 141.
# Fetched 50 bills from page 142.
# Fetched 50 bills from page 143.
# Fetched 50 bills from page 144.
# Fetched 50 bills from page 145.
# Fetched 50 bills from page 146.
# Fetched 50 bills from page 147.
# Fetched 50 bills from page 148.
# Fetched 50 bills from page 149.
# Fetched 50 bills from page 150.
# Fetched 50 bills from page 151.
# Fetched 50 bills from page 152.
# Fetched 50 bills from page 153.
# Fetched 50 bills from page 154.
# Fetched 50 bills from page 155.
# Fetched 50 bills from page 156.
# Fetched 50 bills from page 157.
# Fetched 50 bills from page 158.
# Fetched 50 bills from page 159.
# Fetched 50 bills from page 160.
# Fetched 50 bills from page 161.
# Fetched 50 bills from page 162.
# Fetched 50 bills from page 163.
# Fetched 50 bills from page 164.
# Fetched 50 bills from page 165.
# Fetched 50 bills from page 166.
# Fetched 50 bills from page 167.
# Fetched 50 bills from page 168.
# Fetched 50 bills from page 169.
# Fetched 50 bills from page 170.
# Fetched 50 bills from page 171.
# Fetched 50 bills from page 172.
# Fetched 50 bills from page 173.
# Fetched 50 bills from page 174.
# Fetched 50 bills from page 175.
# Fetched 50 bills from page 176.
# Fetched 50 bills from page 177.
# Fetched 50 bills from page 178.
# Fetched 50 bills from page 179.
# Fetched 50 bills from page 180.
# Fetched 50 bills from page 181.
# Fetched 50 bills from page 182.
# Fetched 50 bills from page 183.
# Fetched 50 bills from page 184.
# Fetched 50 bills from page 185.
# Fetched 50 bills from page 186.
# Fetched 50 bills from page 187.
# Fetched 50 bills from page 188.
# Fetched 50 bills from page 189.
# Fetched 50 bills from page 190.
# Fetched 50 bills from page 191.
# Fetched 50 bills from page 192.
# Fetched 50 bills from page 193.
# Fetched 50 bills from page 194.
# Fetched 50 bills from page 195.
# Fetched 50 bills from page 196.
# Fetched 50 bills from page 197.
# Fetched 50 bills from page 198.
# Fetched 50 bills from page 199.
# Fetched 50 bills from page 200.
# Fetched 50 bills from page 201.
# Fetched 50 bills from page 202.
# Fetched 50 bills from page 203.
# Fetched 50 bills from page 204.
# Fetched 50 bills from page 205.
# Fetched 50 bills from page 206.
# Fetched 50 bills from page 207.
# Fetched 50 bills from page 208.
# Fetched 50 bills from page 209.
# Fetched 50 bills from page 210.
# Fetched 50 bills from page 211.
# Fetched 50 bills from page 212.
# Fetched 50 bills from page 213.
# Fetched 50 bills from page 214.
# Fetched 50 bills from page 215.
# Fetched 50 bills from page 216.
# Fetched 50 bills from page 217.
# Fetched 50 bills from page 218.
# Fetched 50 bills from page 219.
# Fetched 50 bills from page 220.
# Fetched 50 bills from page 221.
# Fetched 50 bills from page 222.
# Fetched 50 bills from page 223.
# Fetched 50 bills from page 224.
# Fetched 50 bills from page 225.
# Fetched 50 bills from page 226.
# Fetched 50 bills from page 227.
# Fetched 50 bills from page 228.
# Fetched 50 bills from page 229.
# Fetched 50 bills from page 230.
# Fetched 50 bills from page 231.
# Fetched 50 bills from page 232.
# Fetched 50 bills from page 233.
# Fetched 50 bills from page 234.
# Fetched 50 bills from page 235.
# Fetched 50 bills from page 236.
# Fetched 50 bills from page 237.
# Fetched 50 bills from page 238.
# Fetched 50 bills from page 239.
# Fetched 50 bills from page 240.
# Fetched 50 bills from page 241.
# Fetched 50 bills from page 242.
# Fetched 50 bills from page 243.
# Fetched 50 bills from page 244.
# Fetched 50 bills from page 245.
# Fetched 50 bills from page 246.
# Fetched 50 bills from page 247.
# Fetched 50 bills from page 248.
# Fetched 50 bills from page 249.
# Fetched 50 bills from page 250.
# Fetched 50 bills from page 251.
# Fetched 50 bills from page 252.
# Fetched 50 bills from page 253.
# Fetched 50 bills from page 254.
# Fetched 50 bills from page 255.
# Fetched 50 bills from page 256.
# Fetched 50 bills from page 257.
# Fetched 50 bills from page 258.
# Fetched 50 bills from page 259.
# Fetched 50 bills from page 260.
# Fetched 50 bills from page 261.
# Fetched 50 bills from page 262.
# Fetched 50 bills from page 263.
# Fetched 50 bills from page 264.
# Fetched 50 bills from page 265.
# Fetched 50 bills from page 266.
# Fetched 50 bills from page 267.
# Fetched 50 bills from page 268.
# Fetched 50 bills from page 269.
# Fetched 50 bills from page 270.
# Fetched 50 bills from page 271.
# Fetched 50 bills from page 272.
# Fetched 50 bills from page 273.
# Fetched 50 bills from page 274.
# Fetched 50 bills from page 275.
# Fetched 50 bills from page 276.
# Fetched 50 bills from page 277.
# Fetched 50 bills from page 278.
# Fetched 50 bills from page 279.
# Fetched 50 bills from page 280.
# Fetched 50 bills from page 281.
# Fetched 50 bills from page 282.
# Fetched 50 bills from page 283.
# Fetched 50 bills from page 284.
# Fetched 50 bills from page 285.
# Fetched 50 bills from page 286.
# Fetched 50 bills from page 287.
# Fetched 50 bills from page 288.
# Fetched 50 bills from page 289.
# Fetched 50 bills from page 290.
# Fetched 50 bills from page 291.
# Fetched 50 bills from page 292.
# Fetched 50 bills from page 293.
# Fetched 50 bills from page 294.
# Fetched 50 bills from page 295.
# Fetched 50 bills from page 296.
# Fetched 50 bills from page 297.
# Fetched 50 bills from page 298.
# Fetched 50 bills from page 299.
# Fetched 50 bills from page 300.
# Fetched 50 bills from page 301.
# Fetched 50 bills from page 302.
# Fetched 50 bills from page 303.
# Fetched 50 bills from page 304.
# Fetched 50 bills from page 305.
# Fetched 50 bills from page 306.
# Fetched 50 bills from page 307.
# Fetched 50 bills from page 308.
# Fetched 50 bills from page 309.
# Fetched 50 bills from page 310.
# Fetched 50 bills from page 311.
# Fetched 50 bills from page 312.
# Fetched 50 bills from page 313.
# Fetched 50 bills from page 314.
# Fetched 50 bills from page 315.
# Fetched 50 bills from page 316.
# Fetched 50 bills from page 317.
# Fetched 50 bills from page 318.
# Fetched 50 bills from page 319.
# Fetched 50 bills from page 320.
# Fetched 50 bills from page 321.
# Fetched 50 bills from page 322.
# Fetched 50 bills from page 323.
# Fetched 50 bills from page 324.
# Fetched 50 bills from page 325.
# Fetched 50 bills from page 326.
# Fetched 50 bills from page 327.
# Fetched 50 bills from page 328.
# Fetched 50 bills from page 329.
# Fetched 50 bills from page 330.
# Fetched 50 bills from page 331.
# Fetched 50 bills from page 332.
# Fetched 50 bills from page 333.
# Fetched 50 bills from page 334.
# Fetched 50 bills from page 335.
# Fetched 50 bills from page 336.
# Fetched 50 bills from page 337.
# Fetched 50 bills from page 338.
# Fetched 50 bills from page 339.
# Fetched 50 bills from page 340.
# Fetched 50 bills from page 341.
# Fetched 50 bills from page 342.
# Fetched 50 bills from page 343.
# Fetched 50 bills from page 344.
# Fetched 50 bills from page 345.
# Fetched 50 bills from page 346.
# Fetched 50 bills from page 347.
# Fetched 50 bills from page 348.
# Fetched 50 bills from page 349.
# Fetched 50 bills from page 350.
# Fetched 50 bills from page 351.
# Fetched 50 bills from page 352.
# Fetched 50 bills from page 353.
# Fetched 50 bills from page 354.
# Fetched 50 bills from page 355.
# Fetched 50 bills from page 356.
# Fetched 50 bills from page 357.
# Fetched 50 bills from page 358.
# Fetched 50 bills from page 359.
# Fetched 50 bills from page 360.
# Fetched 50 bills from page 361.
# Fetched 50 bills from page 362.
# Fetched 50 bills from page 363.
# Fetched 50 bills from page 364.
# Fetched 50 bills from page 365.
# Fetched 50 bills from page 366.
# Fetched 50 bills from page 367.
# Fetched 50 bills from page 368.
# Fetched 50 bills from page 369.
# Fetched 50 bills from page 370.
# Fetched 50 bills from page 371.
# Fetched 50 bills from page 372.
# Fetched 50 bills from page 373.
# Fetched 50 bills from page 374.
# Fetched 50 bills from page 375.
# Fetched 50 bills from page 376.
# Fetched 50 bills from page 377.
# Fetched 50 bills from page 378.
# Fetched 50 bills from page 379.
# Fetched 50 bills from page 380.
# Fetched 50 bills from page 381.
# Fetched 50 bills from page 382.
# Fetched 50 bills from page 383.
# Fetched 50 bills from page 384.
# Fetched 50 bills from page 385.
# Fetched 50 bills from page 386.
# Fetched 50 bills from page 387.
# Fetched 50 bills from page 388.
# Fetched 50 bills from page 389.
# Fetched 50 bills from page 390.
# Fetched 50 bills from page 391.
# Fetched 50 bills from page 392.
# Fetched 50 bills from page 393.
# Fetched 50 bills from page 394.
# Fetched 50 bills from page 395.
# Fetched 50 bills from page 396.
# Fetched 50 bills from page 397.
# Fetched 50 bills from page 398.
# Fetched 50 bills from page 399.
# Fetched 50 bills from page 400.
# Fetched 50 bills from page 401.
# Fetched 50 bills from page 402.
# Fetched 50 bills from page 403.
# Fetched 50 bills from page 404.
# Fetched 50 bills from page 405.
# Fetched 50 bills from page 406.
# Fetched 50 bills from page 407.
# Fetched 50 bills from page 408.
# Fetched 50 bills from page 409.
# Fetched 50 bills from page 410.
# Fetched 50 bills from page 411.
# Fetched 50 bills from page 412.
# Fetched 50 bills from page 413.
# Fetched 50 bills from page 414.
# Fetched 50 bills from page 415.
# Fetched 50 bills from page 416.
# Fetched 50 bills from page 417.
# Fetched 50 bills from page 418.
# Fetched 50 bills from page 419.
# Fetched 50 bills from page 420.
# Fetched 50 bills from page 421.
# Fetched 50 bills from page 422.
# Fetched 50 bills from page 423.
# Fetched 50 bills from page 424.
# Fetched 50 bills from page 425.
# Fetched 50 bills from page 426.
# Fetched 50 bills from page 427.
# Fetched 50 bills from page 428.
# Fetched 50 bills from page 429.
# Fetched 50 bills from page 430.
# Fetched 50 bills from page 431.
# Fetched 50 bills from page 432.
# Fetched 50 bills from page 433.
# Fetched 50 bills from page 434.
# Fetched 50 bills from page 435.
# Fetched 50 bills from page 436.
# Fetched 50 bills from page 437.
# Fetched 50 bills from page 438.
# Fetched 50 bills from page 439.
# Fetched 50 bills from page 440.
# Fetched 50 bills from page 441.
# Fetched 50 bills from page 442.
# Fetched 50 bills from page 443.
# Fetched 50 bills from page 444.
# Fetched 50 bills from page 445.
# Fetched 50 bills from page 446.
# Fetched 50 bills from page 447.
# Fetched 50 bills from page 448.
# Fetched 50 bills from page 449.
# Fetched 50 bills from page 450.
# Fetched 50 bills from page 451.
# Fetched 50 bills from page 452.
# Fetched 50 bills from page 453.
# Fetched 50 bills from page 454.
# Fetched 50 bills from page 455.
# Fetched 50 bills from page 456.
# Fetched 50 bills from page 457.
# Fetched 50 bills from page 458.
# Fetched 50 bills from page 459.
# Fetched 50 bills from page 460.
# Fetched 50 bills from page 461.
# Fetched 50 bills from page 462.
# Fetched 50 bills from page 463.
# Fetched 50 bills from page 464.
# Fetched 50 bills from page 465.
# Fetched 50 bills from page 466.
# Fetched 50 bills from page 467.
# Fetched 50 bills from page 468.
# Fetched 50 bills from page 469.
# Fetched 50 bills from page 470.
# Fetched 50 bills from page 471.
# Fetched 50 bills from page 472.
# Fetched 50 bills from page 473.
# Fetched 50 bills from page 474.
# Fetched 50 bills from page 475.
# Fetched 50 bills from page 476.
# Fetched 50 bills from page 477.
# Fetched 50 bills from page 478.
# Fetched 50 bills from page 479.
# Fetched 50 bills from page 480.
# Fetched 50 bills from page 481.
# Fetched 50 bills from page 482.
# Fetched 50 bills from page 483.
# Fetched 50 bills from page 484.
# Fetched 50 bills from page 485.
# Fetched 50 bills from page 486.
# Fetched 50 bills from page 487.
# Fetched 50 bills from page 488.
# Fetched 50 bills from page 489.
# Fetched 50 bills from page 490.
# Fetched 50 bills from page 491.
# Fetched 50 bills from page 492.
# Fetched 50 bills from page 493.
# Fetched 50 bills from page 494.
# Fetched 50 bills from page 495.
# Fetched 50 bills from page 496.
# Fetched 50 bills from page 497.
# Fetched 50 bills from page 498.
# Fetched 50 bills from page 499.
# Fetched 50 bills from page 500.
# Fetched 50 bills from page 501.
# Fetched 50 bills from page 502.
# Fetched 50 bills from page 503.
# Fetched 50 bills from page 504.
# Fetched 50 bills from page 505.
# Fetched 50 bills from page 506.
# Fetched 50 bills from page 507.
# Fetched 50 bills from page 508.
# Fetched 50 bills from page 509.
# Fetched 50 bills from page 510.
# Fetched 50 bills from page 511.
# Fetched 50 bills from page 512.
# Fetched 50 bills from page 513.
# Fetched 50 bills from page 514.
# Fetched 50 bills from page 515.
# Fetched 50 bills from page 516.
# Fetched 50 bills from page 517.
# Fetched 50 bills from page 518.
# Fetched 50 bills from page 519.
# Fetched 50 bills from page 520.
# Fetched 50 bills from page 521.
# Fetched 50 bills from page 522.
# Fetched 50 bills from page 523.
# Fetched 50 bills from page 524.
# Fetched 50 bills from page 525.
# Fetched 50 bills from page 526.
# Fetched 50 bills from page 527.
# Fetched 50 bills from page 528.
# Fetched 50 bills from page 529.
# Fetched 50 bills from page 530.
# Fetched 50 bills from page 531.
# Fetched 50 bills from page 532.
# Fetched 50 bills from page 533.
# Fetched 50 bills from page 534.
# Fetched 50 bills from page 535.
# Fetched 50 bills from page 536.
# Fetched 50 bills from page 537.
# Fetched 50 bills from page 538.
# Fetched 50 bills from page 539.
# Fetched 50 bills from page 540.
# Fetched 50 bills from page 541.
# Fetched 50 bills from page 542.
# Fetched 50 bills from page 543.
# Fetched 50 bills from page 544.
# Fetched 50 bills from page 545.
# Fetched 50 bills from page 546.
# Fetched 50 bills from page 547.
# Fetched 50 bills from page 548.
# Fetched 50 bills from page 549.
# Fetched 50 bills from page 550.
# Fetched 50 bills from page 551.
# Fetched 50 bills from page 552.
# Fetched 50 bills from page 553.
# Fetched 50 bills from page 554.
# Fetched 50 bills from page 555.
# Fetched 50 bills from page 556.
# Fetched 50 bills from page 557.
# Fetched 50 bills from page 558.
# Fetched 50 bills from page 559.
# Fetched 50 bills from page 560.
# Fetched 50 bills from page 561.
# Fetched 50 bills from page 562.
# Fetched 50 bills from page 563.
# Fetched 50 bills from page 564.
# Fetched 50 bills from page 565.
# Fetched 50 bills from page 566.
# Fetched 50 bills from page 567.
# Fetched 50 bills from page 568.
# Fetched 50 bills from page 569.
# Fetched 50 bills from page 570.
# Fetched 50 bills from page 571.
# Fetched 50 bills from page 572.
# Fetched 50 bills from page 573.
# Fetched 50 bills from page 574.
# Fetched 50 bills from page 575.
# Fetched 50 bills from page 576.
# Fetched 50 bills from page 577.
# Fetched 50 bills from page 578.
# Fetched 50 bills from page 579.
# Fetched 50 bills from page 580.
# Fetched 50 bills from page 581.
# Fetched 50 bills from page 582.
# Fetched 50 bills from page 583.
# Fetched 50 bills from page 584.
# Fetched 50 bills from page 585.
# Fetched 50 bills from page 586.
# Fetched 50 bills from page 587.
# Fetched 50 bills from page 588.
# Fetched 50 bills from page 589.
# Fetched 50 bills from page 590.
# Fetched 50 bills from page 591.
# Fetched 50 bills from page 592.
# Fetched 50 bills from page 593.
# Fetched 50 bills from page 594.
# Fetched 50 bills from page 595.
# Fetched 50 bills from page 596.
# Fetched 50 bills from page 597.
# Fetched 50 bills from page 598.
# Fetched 50 bills from page 599.
# Fetched 50 bills from page 600.
# Fetched 50 bills from page 601.
# Fetched 50 bills from page 602.
# Fetched 50 bills from page 603.
# Fetched 50 bills from page 604.
# Fetched 50 bills from page 605.
# Fetched 50 bills from page 606.
# Fetched 50 bills from page 607.
# Fetched 50 bills from page 608.
# Fetched 50 bills from page 609.
# Fetched 50 bills from page 610.
# Fetched 50 bills from page 611.
# Fetched 50 bills from page 612.
# Fetched 50 bills from page 613.
# Fetched 50 bills from page 614.
# Fetched 50 bills from page 615.
# Fetched 50 bills from page 616.
# Fetched 50 bills from page 617.
# Fetched 50 bills from page 618.
# Fetched 50 bills from page 619.
# Fetched 50 bills from page 620.
# Fetched 50 bills from page 621.
# Fetched 50 bills from page 622.
# Fetched 50 bills from page 623.
# Fetched 50 bills from page 624.
# Fetched 50 bills from page 625.
# Fetched 50 bills from page 626.
# Fetched 50 bills from page 627.
# Fetched 50 bills from page 628.
# Fetched 50 bills from page 629.
# Fetched 50 bills from page 630.
# Fetched 50 bills from page 631.
# Fetched 50 bills from page 632.
# Fetched 50 bills from page 633.
# Fetched 50 bills from page 634.
# Fetched 50 bills from page 635.
# Fetched 50 bills from page 636.
# Fetched 50 bills from page 637.
# Fetched 50 bills from page 638.
# Fetched 50 bills from page 639.
# Fetched 50 bills from page 640.
# Fetched 50 bills from page 641.
# Fetched 50 bills from page 642.
# Fetched 50 bills from page 643.
# Fetched 50 bills from page 644.
# Fetched 50 bills from page 645.
# Fetched 50 bills from page 646.
# Fetched 50 bills from page 647.
# Fetched 50 bills from page 648.
# Fetched 50 bills from page 649.
# Fetched 50 bills from page 650.
# Fetched 50 bills from page 651.
# Fetched 50 bills from page 652.
# Fetched 50 bills from page 653.
# Fetched 50 bills from page 654.
# Fetched 50 bills from page 655.
# Fetched 50 bills from page 656.
# Fetched 50 bills from page 657.
# Fetched 50 bills from page 658.
# Fetched 50 bills from page 659.
# Fetched 50 bills from page 660.
# Fetched 50 bills from page 661.
# Fetched 50 bills from page 662.
# Fetched 50 bills from page 663.
# Fetched 50 bills from page 664.
# Fetched 50 bills from page 665.
# Fetched 50 bills from page 666.
# Fetched 50 bills from page 667.
# Fetched 50 bills from page 668.
# Fetched 50 bills from page 669.
# Fetched 50 bills from page 670.
# Fetched 50 bills from page 671.
# Fetched 50 bills from page 672.
# Fetched 50 bills from page 673.
# Fetched 50 bills from page 674.
# Fetched 50 bills from page 675.
# Fetched 50 bills from page 676.
# Fetched 50 bills from page 677.
# Fetched 50 bills from page 678.
# Fetched 50 bills from page 679.
# Fetched 50 bills from page 680.
# Fetched 50 bills from page 681.
# Fetched 50 bills from page 682.
# Fetched 50 bills from page 683.
# Fetched 50 bills from page 684.
# Fetched 50 bills from page 685.
# Fetched 50 bills from page 686.
# Fetched 50 bills from page 687.
# Fetched 50 bills from page 688.
# Fetched 50 bills from page 689.
# Fetched 50 bills from page 690.
# Fetched 50 bills from page 691.
# Fetched 50 bills from page 692.
# Fetched 50 bills from page 693.
# Fetched 50 bills from page 694.
# Fetched 50 bills from page 695.
# Fetched 50 bills from page 696.
# Fetched 50 bills from page 697.
# Fetched 50 bills from page 698.
# Fetched 50 bills from page 699.
# Fetched 50 bills from page 700.
# Fetched 50 bills from page 701.
# Fetched 50 bills from page 702.
# Fetched 50 bills from page 703.
# Fetched 50 bills from page 704.
# Fetched 50 bills from page 705.
# Fetched 50 bills from page 706.
# Fetched 50 bills from page 707.
# Fetched 50 bills from page 708.
# Fetched 50 bills from page 709.
# Fetched 50 bills from page 710.
# Fetched 50 bills from page 711.
# Fetched 50 bills from page 712.
# Fetched 50 bills from page 713.
# Fetched 50 bills from page 714.
# Fetched 50 bills from page 715.
# Fetched 50 bills from page 716.
# Fetched 50 bills from page 717.
# Fetched 50 bills from page 718.
# Fetched 50 bills from page 719.
# Fetched 50 bills from page 720.
# Fetched 50 bills from page 721.
# Fetched 50 bills from page 722.
# Fetched 50 bills from page 723.
# Fetched 50 bills from page 724.
# Fetched 50 bills from page 725.
# Fetched 50 bills from page 726.
# Fetched 50 bills from page 727.
# Fetched 50 bills from page 728.
# Fetched 50 bills from page 729.
# Fetched 50 bills from page 730.
# Fetched 50 bills from page 731.
# Fetched 50 bills from page 732.
# Fetched 50 bills from page 733.
# Fetched 50 bills from page 734.
# Fetched 50 bills from page 735.
# Fetched 50 bills from page 736.
# Fetched 50 bills from page 737.
# Fetched 50 bills from page 738.
# Fetched 50 bills from page 739.
# Fetched 50 bills from page 740.
# Fetched 50 bills from page 741.
# Fetched 50 bills from page 742.
# Fetched 50 bills from page 743.
# Fetched 50 bills from page 744.
# Fetched 50 bills from page 745.
# Fetched 50 bills from page 746.
# Fetched 50 bills from page 747.
# Fetched 50 bills from page 748.
# Fetched 50 bills from page 749.
# Fetched 50 bills from page 750.
# Fetched 50 bills from page 751.
# Fetched 50 bills from page 752.
# Fetched 50 bills from page 753.
# Fetched 50 bills from page 754.
# Fetched 50 bills from page 755.
# Fetched 50 bills from page 756.
# Fetched 50 bills from page 757.
# Fetched 50 bills from page 758.
# Fetched 50 bills from page 759.
# Fetched 50 bills from page 760.
# Fetched 50 bills from page 761.
# Fetched 50 bills from page 762.
# Fetched 50 bills from page 763.
# Fetched 50 bills from page 764.
# Fetched 50 bills from page 765.
# Fetched 50 bills from page 766.
# Fetched 50 bills from page 767.
# Fetched 50 bills from page 768.
# Fetched 50 bills from page 769.
# Fetched 50 bills from page 770.
# Fetched 50 bills from page 771.
# Fetched 50 bills from page 772.
# Fetched 50 bills from page 773.
# Fetched 50 bills from page 774.
# Fetched 50 bills from page 775.
# Fetched 50 bills from page 776.
# Fetched 50 bills from page 777.
# Fetched 50 bills from page 778.
# Fetched 50 bills from page 779.
# Fetched 50 bills from page 780.
# Fetched 50 bills from page 781.
# Fetched 50 bills from page 782.
# Fetched 50 bills from page 783.
# Fetched 50 bills from page 784.
# Fetched 50 bills from page 785.
# Fetched 50 bills from page 786.
# Fetched 50 bills from page 787.
# Fetched 50 bills from page 788.
# Fetched 50 bills from page 789.
# Fetched 50 bills from page 790.
# Fetched 50 bills from page 791.
# Fetched 50 bills from page 792.
# Fetched 50 bills from page 793.
# Fetched 50 bills from page 794.
# Fetched 50 bills from page 795.
# Fetched 50 bills from page 796.
# Fetched 50 bills from page 797.
# Fetched 50 bills from page 798.
# Fetched 50 bills from page 799.
# Fetched 50 bills from page 800.
# Fetched 50 bills from page 801.
# Fetched 50 bills from page 802.
# Fetched 50 bills from page 803.
# Fetched 50 bills from page 804.
# Fetched 50 bills from page 805.
# Fetched 50 bills from page 806.
# Fetched 50 bills from page 807.
# Fetched 50 bills from page 808.
# Fetched 50 bills from page 809.
# Fetched 50 bills from page 810.
# Fetched 50 bills from page 811.
# Fetched 50 bills from page 812.
# Fetched 50 bills from page 813.
# Fetched 50 bills from page 814.
# Fetched 50 bills from page 815.
# Fetched 50 bills from page 816.
# Fetched 50 bills from page 817.
# Fetched 50 bills from page 818.
# Fetched 50 bills from page 819.
# Fetched 50 bills from page 820.
# Fetched 50 bills from page 821.
# Fetched 50 bills from page 822.
# Fetched 50 bills from page 823.
# Fetched 50 bills from page 824.
# Fetched 50 bills from page 825.
# Fetched 50 bills from page 826.
# Fetched 50 bills from page 827.
# Fetched 50 bills from page 828.
# Fetched 50 bills from page 829.
# Fetched 50 bills from page 830.
# Fetched 50 bills from page 831.
# Fetched 50 bills from page 832.
# Fetched 50 bills from page 833.
# Fetched 50 bills from page 834.
# Fetched 50 bills from page 835.
# Fetched 50 bills from page 836.
# Fetched 50 bills from page 837.
# Fetched 50 bills from page 838.
# Fetched 50 bills from page 839.
# Fetched 50 bills from page 840.
# Fetched 50 bills from page 841.
# Fetched 50 bills from page 842.
# Fetched 50 bills from page 843.
# Fetched 50 bills from page 844.
# Fetched 50 bills from page 845.
# Fetched 50 bills from page 846.
# Fetched 50 bills from page 847.
# Fetched 50 bills from page 848.
# Fetched 50 bills from page 849.
# Fetched 50 bills from page 850.
# Fetched 50 bills from page 851.
# Fetched 50 bills from page 852.
# Fetched 50 bills from page 853.
# Fetched 50 bills from page 854.
# Fetched 50 bills from page 855.
# Fetched 50 bills from page 856.
# Fetched 50 bills from page 857.
# Fetched 50 bills from page 858.
# Fetched 50 bills from page 859.
# Fetched 50 bills from page 860.
# Fetched 50 bills from page 861.
# Fetched 50 bills from page 862.
# Fetched 50 bills from page 863.
# Fetched 50 bills from page 864.
# Fetched 50 bills from page 865.
# Fetched 50 bills from page 866.
# Fetched 50 bills from page 867.
# Fetched 50 bills from page 868.
# Fetched 50 bills from page 869.
# Fetched 50 bills from page 870.
# Fetched 50 bills from page 871.
# Fetched 50 bills from page 872.
# Fetched 50 bills from page 873.
# Fetched 50 bills from page 874.
# Fetched 50 bills from page 875.
# Fetched 50 bills from page 876.
# Fetched 50 bills from page 877.
# Fetched 50 bills from page 878.
# Fetched 50 bills from page 879.
# Fetched 50 bills from page 880.
# Fetched 50 bills from page 881.
# Fetched 50 bills from page 882.
# Fetched 50 bills from page 883.
# Fetched 50 bills from page 884.
# Fetched 50 bills from page 885.
# Fetched 50 bills from page 886.
# Fetched 50 bills from page 887.
# Fetched 50 bills from page 888.
# Fetched 50 bills from page 889.
# Fetched 50 bills from page 890.
# Fetched 50 bills from page 891.
# Fetched 50 bills from page 892.
# Fetched 50 bills from page 893.
# Fetched 50 bills from page 894.
# Fetched 50 bills from page 895.
# Fetched 50 bills from page 896.
# Fetched 50 bills from page 897.
# Fetched 50 bills from page 898.
# Fetched 50 bills from page 899.
# Fetched 50 bills from page 900.
# Fetched 50 bills from page 901.
# Fetched 50 bills from page 902.
# Fetched 50 bills from page 903.
# Fetched 50 bills from page 904.
# Fetched 50 bills from page 905.
# Fetched 50 bills from page 906.
# Fetched 50 bills from page 907.
# Fetched 50 bills from page 908.
# Fetched 50 bills from page 909.
# Fetched 50 bills from page 910.
# Fetched 50 bills from page 911.
# Fetched 50 bills from page 912.
# Fetched 50 bills from page 913.
# Fetched 50 bills from page 914.
# Fetched 50 bills from page 915.
# Fetched 50 bills from page 916.
# Fetched 50 bills from page 917.
# Fetched 50 bills from page 918.
# Fetched 50 bills from page 919.
# Fetched 50 bills from page 920.
# Fetched 50 bills from page 921.
# Fetched 50 bills from page 922.
# Fetched 50 bills from page 923.
# Fetched 50 bills from page 924.
# Fetched 50 bills from page 925.
# Fetched 50 bills from page 926.
# Fetched 50 bills from page 927.
# Fetched 50 bills from page 928.
# Fetched 50 bills from page 929.
# Fetched 50 bills from page 930.
# Fetched 50 bills from page 931.
# Fetched 50 bills from page 932.
# Fetched 50 bills from page 933.
# Fetched 50 bills from page 934.
# Fetched 50 bills from page 935.
# Fetched 50 bills from page 936.
# Fetched 50 bills from page 937.
# Fetched 50 bills from page 938.
# Fetched 50 bills from page 939.
# Fetched 50 bills from page 940.
# Fetched 50 bills from page 941.
# Fetched 50 bills from page 942.
# Fetched 50 bills from page 943.
# Fetched 50 bills from page 944.
# Fetched 50 bills from page 945.
# Fetched 50 bills from page 946.
# Fetched 50 bills from page 947.
# Fetched 50 bills from page 948.
# Fetched 50 bills from page 949.
# Fetched 50 bills from page 950.
# Fetched 50 bills from page 951.
# Fetched 50 bills from page 952.
# Fetched 50 bills from page 953.
# Fetched 50 bills from page 954.
# Fetched 50 bills from page 955.
# Fetched 50 bills from page 956.
# Fetched 50 bills from page 957.
# Fetched 50 bills from page 958.
# Fetched 50 bills from page 959.
# Fetched 50 bills from page 960.
# Fetched 50 bills from page 961.
# Fetched 50 bills from page 962.
# Fetched 50 bills from page 963.
# Fetched 50 bills from page 964.
# Fetched 50 bills from page 965.
# Fetched 50 bills from page 966.
# Fetched 50 bills from page 967.
# Fetched 50 bills from page 968.
# Fetched 50 bills from page 969.
# Fetched 50 bills from page 970.
# Fetched 50 bills from page 971.
# Fetched 50 bills from page 972.
# Fetched 50 bills from page 973.
# Fetched 50 bills from page 974.
# Fetched 50 bills from page 975.
# Fetched 50 bills from page 976.
# Fetched 50 bills from page 977.
# Fetched 50 bills from page 978.
# Fetched 50 bills from page 979.
# Fetched 50 bills from page 980.
# Fetched 50 bills from page 981.
# Fetched 50 bills from page 982.
# Fetched 50 bills from page 983.
# Fetched 50 bills from page 984.
# Fetched 50 bills from page 985.
# Fetched 50 bills from page 986.
# Fetched 50 bills from page 987.
# Fetched 50 bills from page 988.
# Fetched 50 bills from page 989.
# Fetched 50 bills from page 990.
# Fetched 50 bills from page 991.
# Fetched 50 bills from page 992.
# Fetched 50 bills from page 993.
# Fetched 50 bills from page 994.
# Fetched 50 bills from page 995.
# Fetched 50 bills from page 996.
# Fetched 50 bills from page 997.
# Fetched 50 bills from page 998.
# Fetched 50 bills from page 999.
# Fetched 50 bills from page 1000.
# Fetched 50 bills from page 1001.
# Fetched 50 bills from page 1002.
# Fetched 50 bills from page 1003.
# Fetched 50 bills from page 1004.
# Fetched 50 bills from page 1005.
# Fetched 50 bills from page 1006.
# Fetched 50 bills from page 1007.
# Fetched 50 bills from page 1008.
# Fetched 50 bills from page 1009.
# Fetched 50 bills from page 1010.
# Fetched 50 bills from page 1011.
# Fetched 50 bills from page 1012.
# Fetched 50 bills from page 1013.
# Fetched 50 bills from page 1014.
# Fetched 50 bills from page 1015.
# Fetched 50 bills from page 1016.
# Fetched 50 bills from page 1017.
# Fetched 50 bills from page 1018.
# Fetched 50 bills from page 1019.
# Fetched 50 bills from page 1020.
# Fetched 50 bills from page 1021.
# Fetched 50 bills from page 1022.
# Fetched 50 bills from page 1023.
# Fetched 50 bills from page 1024.
# Fetched 50 bills from page 1025.
# Fetched 50 bills from page 1026.
# Fetched 50 bills from page 1027.
# Fetched 50 bills from page 1028.
# Fetched 50 bills from page 1029.
# Fetched 50 bills from page 1030.
# Fetched 50 bills from page 1031.
# Fetched 50 bills from page 1032.
# Fetched 50 bills from page 1033.
# Fetched 50 bills from page 1034.
# Fetched 50 bills from page 1035.
# Fetched 50 bills from page 1036.
# Fetched 50 bills from page 1037.
# Fetched 50 bills from page 1038.
# Fetched 50 bills from page 1039.
# Fetched 50 bills from page 1040.
# Fetched 50 bills from page 1041.
# Fetched 50 bills from page 1042.
# Fetched 50 bills from page 1043.
# Fetched 50 bills from page 1044.
# Fetched 50 bills from page 1045.
# Fetched 50 bills from page 1046.
# Fetched 50 bills from page 1047.
# Fetched 50 bills from page 1048.
# Fetched 50 bills from page 1049.
# Fetched 50 bills from page 1050.
# Fetched 50 bills from page 1051.
# Fetched 50 bills from page 1052.
# Fetched 50 bills from page 1053.
# Fetched 50 bills from page 1054.
# Fetched 50 bills from page 1055.
# Fetched 50 bills from page 1056.
# Fetched 50 bills from page 1057.
# Fetched 50 bills from page 1058.
# Fetched 50 bills from page 1059.
# Fetched 50 bills from page 1060.
# Fetched 50 bills from page 1061.
# Fetched 50 bills from page 1062.
# Fetched 50 bills from page 1063.
# Fetched 50 bills from page 1064.
# Fetched 50 bills from page 1065.
# Fetched 50 bills from page 1066.
# Fetched 50 bills from page 1067.
# Fetched 50 bills from page 1068.
# Fetched 50 bills from page 1069.
# Fetched 50 bills from page 1070.
# Fetched 50 bills from page 1071.
# Fetched 50 bills from page 1072.
# Fetched 50 bills from page 1073.
# Fetched 50 bills from page 1074.
# Fetched 50 bills from page 1075.
# Fetched 50 bills from page 1076.
# Fetched 50 bills from page 1077.
# Fetched 50 bills from page 1078.
# Fetched 50 bills from page 1079.
# Fetched 50 bills from page 1080.
# Fetched 50 bills from page 1081.
# Fetched 50 bills from page 1082.
# Fetched 50 bills from page 1083.
# Fetched 50 bills from page 1084.
# Fetched 50 bills from page 1085.
# Fetched 50 bills from page 1086.
# Fetched 50 bills from page 1087.
# Fetched 50 bills from page 1088.
# Fetched 50 bills from page 1089.
# Fetched 50 bills from page 1090.
# Fetched 50 bills from page 1091.
# Fetched 50 bills from page 1092.
# Fetched 50 bills from page 1093.
# Fetched 50 bills from page 1094.
# Fetched 50 bills from page 1095.
# Fetched 50 bills from page 1096.
# Fetched 50 bills from page 1097.
# Fetched 50 bills from page 1098.
# Fetched 50 bills from page 1099.
# Fetched 50 bills from page 1100.
# Fetched 50 bills from page 1101.
# Fetched 50 bills from page 1102.
# Fetched 50 bills from page 1103.
# Fetched 50 bills from page 1104.
# Fetched 50 bills from page 1105.
# Fetched 50 bills from page 1106.
# Fetched 50 bills from page 1107.
# Fetched 50 bills from page 1108.
# Fetched 50 bills from page 1109.
# Fetched 50 bills from page 1110.
# Fetched 50 bills from page 1111.
# Fetched 50 bills from page 1112.
# Fetched 50 bills from page 1113.
# Fetched 50 bills from page 1114.
# Fetched 50 bills from page 1115.
# Fetched 50 bills from page 1116.
# Fetched 50 bills from page 1117.
# Fetched 50 bills from page 1118.
# Fetched 50 bills from page 1119.
# Fetched 50 bills from page 1120.
# Fetched 50 bills from page 1121.
# Fetched 50 bills from page 1122.
# Fetched 50 bills from page 1123.
# Fetched 50 bills from page 1124.
# Fetched 50 bills from page 1125.
# Fetched 50 bills from page 1126.
# Fetched 50 bills from page 1127.
# Fetched 50 bills from page 1128.
# Fetched 50 bills from page 1129.
# Fetched 50 bills from page 1130.
# Fetched 50 bills from page 1131.
# Fetched 50 bills from page 1132.
# Fetched 50 bills from page 1133.
# Fetched 50 bills from page 1134.
# Fetched 50 bills from page 1135.
# Fetched 50 bills from page 1136.
# Fetched 50 bills from page 1137.
# Fetched 50 bills from page 1138.
# Fetched 50 bills from page 1139.
# Fetched 50 bills from page 1140.
# Fetched 50 bills from page 1141.
# Fetched 50 bills from page 1142.
# Fetched 50 bills from page 1143.
# Fetched 50 bills from page 1144.
# Fetched 50 bills from page 1145.
# Fetched 50 bills from page 1146.
# Fetched 50 bills from page 1147.
# Fetched 50 bills from page 1148.
# Fetched 50 bills from page 1149.
# Fetched 50 bills from page 1150.
# Fetched 50 bills from page 1151.
# Fetched 50 bills from page 1152.
# Fetched 50 bills from page 1153.
# Fetched 50 bills from page 1154.
# Fetched 50 bills from page 1155.
# Fetched 50 bills from page 1156.
# Fetched 50 bills from page 1157.
# Fetched 50 bills from page 1158.
# Fetched 50 bills from page 1159.
# Fetched 50 bills from page 1160.
# Fetched 50 bills from page 1161.
# Fetched 50 bills from page 1162.
# Fetched 50 bills from page 1163.
# Fetched 50 bills from page 1164.
# Fetched 50 bills from page 1165.
# Fetched 50 bills from page 1166.
# Fetched 50 bills from page 1167.
# Fetched 50 bills from page 1168.
# Fetched 50 bills from page 1169.
# Fetched 50 bills from page 1170.
# Fetched 50 bills from page 1171.
# Fetched 50 bills from page 1172.
# Fetched 50 bills from page 1173.
# Fetched 50 bills from page 1174.
# Fetched 50 bills from page 1175.
# Fetched 50 bills from page 1176.
# Fetched 50 bills from page 1177.
# Fetched 50 bills from page 1178.
# Fetched 50 bills from page 1179.
# Fetched 50 bills from page 1180.
# Fetched 50 bills from page 1181.
# Fetched 50 bills from page 1182.
# Fetched 50 bills from page 1183.
# Fetched 50 bills from page 1184.
# Fetched 50 bills from page 1185.
# Fetched 50 bills from page 1186.
# Fetched 50 bills from page 1187.
# Fetched 50 bills from page 1188.
# Fetched 50 bills from page 1189.
# Fetched 50 bills from page 1190.
# Fetched 50 bills from page 1191.
# Fetched 50 bills from page 1192.
# Fetched 50 bills from page 1193.
# Fetched 50 bills from page 1194.
# Fetched 50 bills from page 1195.
# Fetched 50 bills from page 1196.
# Fetched 50 bills from page 1197.
# Fetched 50 bills from page 1198.
# Fetched 50 bills from page 1199.
# Fetched 50 bills from page 1200.
# Fetched 50 bills from page 1201.
# Fetched 50 bills from page 1202.
# Fetched 50 bills from page 1203.
# Fetched 50 bills from page 1204.
# Fetched 50 bills from page 1205.
# Fetched 50 bills from page 1206.
# Fetched 50 bills from page 1207.
# Fetched 50 bills from page 1208.
# Fetched 50 bills from page 1209.
# Fetched 50 bills from page 1210.
# Fetched 50 bills from page 1211.
# Fetched 50 bills from page 1212.
# Fetched 50 bills from page 1213.
# Fetched 50 bills from page 1214.
# Fetched 50 bills from page 1215.
# Fetched 50 bills from page 1216.
# Fetched 50 bills from page 1217.
# Fetched 50 bills from page 1218.
# Fetched 50 bills from page 1219.
# Fetched 50 bills from page 1220.
# Fetched 50 bills from page 1221.
# Fetched 50 bills from page 1222.
# Fetched 50 bills from page 1223.
# Fetched 50 bills from page 1224.
# Fetched 50 bills from page 1225.
# Fetched 50 bills from page 1226.
# Fetched 50 bills from page 1227.
# Fetched 50 bills from page 1228.
# Fetched 50 bills from page 1229.
# Fetched 50 bills from page 1230.
# Fetched 50 bills from page 1231.
# Fetched 50 bills from page 1232.
# Fetched 50 bills from page 1233.
# Fetched 50 bills from page 1234.
# Fetched 50 bills from page 1235.
# Fetched 50 bills from page 1236.
# Fetched 50 bills from page 1237.
# Fetched 50 bills from page 1238.
# Fetched 50 bills from page 1239.
# Fetched 50 bills from page 1240.
# Fetched 50 bills from page 1241.
# Fetched 50 bills from page 1242.
# Fetched 50 bills from page 1243.
# Fetched 50 bills from page 1244.
# Fetched 50 bills from page 1245.
# Fetched 50 bills from page 1246.
# Fetched 50 bills from page 1247.
# Fetched 50 bills from page 1248.
# Fetched 50 bills from page 1249.
# Fetched 50 bills from page 1250.
# Fetched 50 bills from page 1251.
# Fetched 50 bills from page 1252.
# Fetched 50 bills from page 1253.
# Fetched 50 bills from page 1254.
# Fetched 50 bills from page 1255.
# Fetched 50 bills from page 1256.
# Fetched 50 bills from page 1257.
# Fetched 50 bills from page 1258.
# Fetched 50 bills from page 1259.
# Fetched 50 bills from page 1260.
# Fetched 50 bills from page 1261.
# Fetched 50 bills from page 1262.
# Fetched 50 bills from page 1263.
# Fetched 50 bills from page 1264.
# Fetched 50 bills from page 1265.
# Fetched 50 bills from page 1266.
# Fetched 50 bills from page 1267.
# Fetched 50 bills from page 1268.
# Fetched 50 bills from page 1269.
# Fetched 50 bills from page 1270.
# Fetched 50 bills from page 1271.
# Fetched 50 bills from page 1272.
# Fetched 50 bills from page 1273.
# Fetched 50 bills from page 1274.
# Fetched 50 bills from page 1275.
# Fetched 50 bills from page 1276.
# Fetched 50 bills from page 1277.
# Fetched 50 bills from page 1278.
# Fetched 50 bills from page 1279.
# Fetched 50 bills from page 1280.
# Fetched 50 bills from page 1281.
# Fetched 50 bills from page 1282.
# Fetched 50 bills from page 1283.
# Fetched 50 bills from page 1284.
# Fetched 50 bills from page 1285.
# Fetched 50 bills from page 1286.
# Fetched 50 bills from page 1287.
# Fetched 50 bills from page 1288.
# Fetched 50 bills from page 1289.
# Fetched 50 bills from page 1290.
# Fetched 50 bills from page 1291.
# Fetched 50 bills from page 1292.
# Fetched 50 bills from page 1293.
# Fetched 50 bills from page 1294.
# Fetched 50 bills from page 1295.
# Fetched 50 bills from page 1296.
# Fetched 50 bills from page 1297.
# Fetched 50 bills from page 1298.
# Fetched 50 bills from page 1299.
# Fetched 50 bills from page 1300.
# Fetched 50 bills from page 1301.
# Fetched 50 bills from page 1302.
# Fetched 50 bills from page 1303.
# Fetched 50 bills from page 1304.
# Fetched 50 bills from page 1305.
# Fetched 50 bills from page 1306.
# Fetched 50 bills from page 1307.
# Fetched 50 bills from page 1308.
# Fetched 50 bills from page 1309.
# Fetched 50 bills from page 1310.
# Fetched 50 bills from page 1311.
# Fetched 50 bills from page 1312.
# Fetched 50 bills from page 1313.
# Fetched 50 bills from page 1314.
# Fetched 50 bills from page 1315.
# Fetched 50 bills from page 1316.
# Fetched 50 bills from page 1317.
# Fetched 50 bills from page 1318.
# Fetched 50 bills from page 1319.
# Fetched 50 bills from page 1320.
# Fetched 50 bills from page 1321.
# Fetched 50 bills from page 1322.
# Fetched 50 bills from page 1323.
# Fetched 50 bills from page 1324.
# Fetched 50 bills from page 1325.
# Fetched 50 bills from page 1326.
# Fetched 50 bills from page 1327.
# Fetched 50 bills from page 1328.
# Fetched 50 bills from page 1329.
# Fetched 50 bills from page 1330.
# Fetched 50 bills from page 1331.
# Fetched 50 bills from page 1332.
# Fetched 50 bills from page 1333.
# Fetched 50 bills from page 1334.
# Fetched 50 bills from page 1335.
# Fetched 50 bills from page 1336.
# Fetched 50 bills from page 1337.
# Fetched 50 bills from page 1338.
# Fetched 50 bills from page 1339.
# Fetched 50 bills from page 1340.
# Fetched 50 bills from page 1341.
# Fetched 50 bills from page 1342.
# Fetched 50 bills from page 1343.
# Fetched 50 bills from page 1344.
# Fetched 50 bills from page 1345.
# Fetched 50 bills from page 1346.
# Fetched 50 bills from page 1347.
# Fetched 50 bills from page 1348.
# Fetched 50 bills from page 1349.
# Fetched 50 bills from page 1350.
# Fetched 50 bills from page 1351.
# Fetched 50 bills from page 1352.
# Fetched 50 bills from page 1353.
# Fetched 50 bills from page 1354.
# Fetched 50 bills from page 1355.
# Fetched 50 bills from page 1356.
# Fetched 50 bills from page 1357.
# Fetched 50 bills from page 1358.
# Fetched 50 bills from page 1359.
# Fetched 50 bills from page 1360.
# Fetched 50 bills from page 1361.
# Fetched 50 bills from page 1362.
# Fetched 50 bills from page 1363.
# Fetched 50 bills from page 1364.
# Fetched 50 bills from page 1365.
# Fetched 50 bills from page 1366.
# Fetched 50 bills from page 1367.
# Fetched 50 bills from page 1368.
# Fetched 50 bills from page 1369.
# Fetched 50 bills from page 1370.
# Fetched 50 bills from page 1371.
# Fetched 50 bills from page 1372.
# Fetched 50 bills from page 1373.
# Fetched 50 bills from page 1374.
# Fetched 50 bills from page 1375.
# Fetched 50 bills from page 1376.
# Fetched 50 bills from page 1377.
# Fetched 50 bills from page 1378.
# Fetched 50 bills from page 1379.
# Fetched 50 bills from page 1380.
# Fetched 50 bills from page 1381.
# Fetched 50 bills from page 1382.
# Fetched 50 bills from page 1383.
# Fetched 50 bills from page 1384.
# Fetched 50 bills from page 1385.
# Fetched 50 bills from page 1386.
# Fetched 50 bills from page 1387.
# Fetched 50 bills from page 1388.
# Fetched 50 bills from page 1389.
# Fetched 50 bills from page 1390.
# Fetched 50 bills from page 1391.
# Fetched 50 bills from page 1392.
# Fetched 50 bills from page 1393.
# Fetched 50 bills from page 1394.
# Fetched 50 bills from page 1395.
# Fetched 50 bills from page 1396.
# Fetched 50 bills from page 1397.
# Fetched 50 bills from page 1398.
# Fetched 50 bills from page 1399.
# Fetched 50 bills from page 1400.
# Fetched 50 bills from page 1401.
# Fetched 50 bills from page 1402.
# Fetched 50 bills from page 1403.
# Fetched 50 bills from page 1404.
# Fetched 50 bills from page 1405.
# Fetched 50 bills from page 1406.
# Fetched 50 bills from page 1407.
# Fetched 50 bills from page 1408.
# Fetched 50 bills from page 1409.
# Fetched 50 bills from page 1410.
# Fetched 50 bills from page 1411.
# Fetched 50 bills from page 1412.
# Fetched 50 bills from page 1413.
# Fetched 50 bills from page 1414.
# Fetched 50 bills from page 1415.
# Fetched 50 bills from page 1416.
# Fetched 50 bills from page 1417.
# Fetched 50 bills from page 1418.
# Fetched 50 bills from page 1419.
# Fetched 50 bills from page 1420.
# Fetched 50 bills from page 1421.
# Fetched 50 bills from page 1422.
# Fetched 50 bills from page 1423.
# Fetched 50 bills from page 1424.
# Fetched 50 bills from page 1425.
# Fetched 50 bills from page 1426.
# Fetched 50 bills from page 1427.
# Fetched 50 bills from page 1428.
# Fetched 50 bills from page 1429.
# Fetched 50 bills from page 1430.
# Fetched 50 bills from page 1431.
# Fetched 50 bills from page 1432.
# Fetched 50 bills from page 1433.
# Fetched 50 bills from page 1434.
# Fetched 50 bills from page 1435.
# Fetched 50 bills from page 1436.
# Fetched 50 bills from page 1437.
# Fetched 50 bills from page 1438.
# Fetched 50 bills from page 1439.
# Fetched 50 bills from page 1440.
# Fetched 50 bills from page 1441.
# Fetched 50 bills from page 1442.
# Fetched 50 bills from page 1443.
# Fetched 50 bills from page 1444.
# Fetched 50 bills from page 1445.
# Fetched 50 bills from page 1446.
# Fetched 50 bills from page 1447.
# Fetched 50 bills from page 1448.
# Fetched 50 bills from page 1449.
# Fetched 50 bills from page 1450.
# Fetched 50 bills from page 1451.
# Fetched 50 bills from page 1452.
# Fetched 50 bills from page 1453.
# Fetched 50 bills from page 1454.
# Fetched 50 bills from page 1455.
# Fetched 50 bills from page 1456.
# Fetched 50 bills from page 1457.
# Fetched 50 bills from page 1458.
# Fetched 50 bills from page 1459.
# Fetched 50 bills from page 1460.
# Fetched 50 bills from page 1461.
# Fetched 50 bills from page 1462.
# Fetched 50 bills from page 1463.
# Fetched 50 bills from page 1464.
# Fetched 50 bills from page 1465.
# Fetched 50 bills from page 1466.
# Fetched 50 bills from page 1467.
# Fetched 50 bills from page 1468.
# Fetched 50 bills from page 1469.
# Fetched 50 bills from page 1470.
# Fetched 50 bills from page 1471.
# Fetched 50 bills from page 1472.
# Fetched 50 bills from page 1473.
# Fetched 50 bills from page 1474.
# Fetched 50 bills from page 1475.
# Fetched 50 bills from page 1476.
# Fetched 50 bills from page 1477.
# Fetched 50 bills from page 1478.
# Fetched 50 bills from page 1479.
# Fetched 50 bills from page 1480.
# Fetched 50 bills from page 1481.
# Fetched 50 bills from page 1482.
# Fetched 50 bills from page 1483.
# Fetched 50 bills from page 1484.
# Fetched 50 bills from page 1485.
# Fetched 50 bills from page 1486.
# Fetched 50 bills from page 1487.
# Fetched 50 bills from page 1488.
# ...
# Fetched 50 bills from page 3325.
# Fetched 50 bills from page 3326.
# Fetched 50 bills from page 3327.
# Fetched 50 bills from page 3328.
# Fetched 50 bills from page 3329.
# Fetched 50 bills from page 3330.
# Fetched 50 bills from page 3331.
# Fetched 50 bills from page 3332.
# Fetched 50 bills from page 3333.
# Fetched 50 bills from page 3334.
# Fetched 50 bills from page 3335.
# Fetched 50 bills from page 3336.
# Fetched 50 bills from page 3337.
# Fetched 50 bills from page 3338.
# Fetched 50 bills from page 3339.
# Fetched 50 bills from page 3340.
# Fetched 50 bills from page 3341.
# Fetched 50 bills from page 3342.
# Fetched 50 bills from page 3343.
# Fetched 50 bills from page 3344.
# Fetched 50 bills from page 3345.
# Fetched 50 bills from page 3346.
# Fetched 50 bills from page 3347.
# Fetched 50 bills from page 3348.
# Fetched 50 bills from page 3349.
# Fetched 50 bills from page 3350.
# Fetched 50 bills from page 3351.
# Fetched 50 bills from page 3352.
# Fetched 50 bills from page 3353.
# Fetched 50 bills from page 3354.
# Fetched 50 bills from page 3355.
# Fetched 50 bills from page 3356.
# Fetched 50 bills from page 3357.
# Fetched 50 bills from page 3358.
# Fetched 50 bills from page 3359.
# Fetched 50 bills from page 3360.
# Fetched 50 bills from page 3361.
# Fetched 50 bills from page 3362.
# Fetched 50 bills from page 3363.
# Fetched 50 bills from page 3364.
# Fetched 50 bills from page 3365.
# Fetched 50 bills from page 3366.
# Fetched 50 bills from page 3367.
# Fetched 50 bills from page 3368.
# Fetched 50 bills from page 3369.
# Fetched 50 bills from page 3370.
# Fetched 50 bills from page 3371.
# Fetched 50 bills from page 3372.
# Fetched 50 bills from page 3373.
# Fetched 50 bills from page 3374.
# Fetched 50 bills from page 3375.
# Fetched 50 bills from page 3376.
# Fetched 50 bills from page 3377.
# Fetched 50 bills from page 3378.
# Fetched 50 bills from page 3379.
# Fetched 50 bills from page 3380.
# Fetched 50 bills from page 3381.
# Fetched 50 bills from page 3382.
# Fetched 50 bills from page 3383.
# Fetched 50 bills from page 3384.
# Fetched 50 bills from page 3385.
# Fetched 50 bills from page 3386.
# Fetched 50 bills from page 3387.
# Fetched 50 bills from page 3388.
# Fetched 50 bills from page 3389.
# Fetched 50 bills from page 3390.
# Fetched 50 bills from page 3391.
# Fetched 50 bills from page 3392.
# Fetched 50 bills from page 3393.
# Fetched 50 bills from page 3394.
# Fetched 50 bills from page 3395.
# Fetched 50 bills from page 3396.
# Fetched 50 bills from page 3397.
# Fetched 50 bills from page 3398.
# Fetched 50 bills from page 3399.
# Fetched 50 bills from page 3400.
# Fetched 50 bills from page 3401.
# Fetched 50 bills from page 3402.
# Fetched 50 bills from page 3403.
# Fetched 50 bills from page 3404.
# Fetched 50 bills from page 3405.
# Fetched 50 bills from page 3406.
# Fetched 50 bills from page 3407.
# Fetched 50 bills from page 3408.
# Fetched 50 bills from page 3409.
# Fetched 50 bills from page 3410.
# Fetched 50 bills from page 3411.
# Fetched 50 bills from page 3412.
# Fetched 50 bills from page 3413.
# Fetched 50 bills from page 3414.
# Fetched 50 bills from page 3415.
# Fetched 50 bills from page 3416.
# Fetched 50 bills from page 3417.
# Fetched 50 bills from page 3418.
# Fetched 50 bills from page 3419.
# Fetched 50 bills from page 3420.
# Fetched 50 bills from page 3421.
# Fetched 50 bills from page 3422.
# Fetched 50 bills from page 3423.
# Fetched 50 bills from page 3424.
# Fetched 50 bills from page 3425.
# Fetched 50 bills from page 3426.
# Fetched 50 bills from page 3427.
# Fetched 50 bills from page 3428.
# Fetched 50 bills from page 3429.
# Fetched 50 bills from page 3430.
# Fetched 50 bills from page 3431.
# Fetched 50 bills from page 3432.
# Fetched 50 bills from page 3433.
# Fetched 50 bills from page 3434.
# Fetched 50 bills from page 3435.
# Fetched 50 bills from page 3436.
# Fetched 50 bills from page 3437.
# Fetched 50 bills from page 3438.
# Fetched 50 bills from page 3439.
# Fetched 50 bills from page 3440.
# Fetched 50 bills from page 3441.
# Fetched 50 bills from page 3442.
# Fetched 50 bills from page 3443.
# Fetched 50 bills from page 3444.
# Fetched 50 bills from page 3445.
# Fetched 50 bills from page 3446.
# Fetched 50 bills from page 3447.
# Fetched 50 bills from page 3448.
# Fetched 50 bills from page 3449.
# Fetched 50 bills from page 3450.
# Fetched 50 bills from page 3451.
# Fetched 50 bills from page 3452.
# Fetched 50 bills from page 3453.
# Fetched 50 bills from page 3454.
# Fetched 50 bills from page 3455.
# Fetched 50 bills from page 3456.
# Fetched 50 bills from page 3457.
# Fetched 50 bills from page 3458.
# Fetched 50 bills from page 3459.
# Fetched 50 bills from page 3460.
# Fetched 50 bills from page 3461.
# Fetched 50 bills from page 3462.
# Fetched 50 bills from page 3463.
# Fetched 50 bills from page 3464.
# Fetched 50 bills from page 3465.
# Fetched 50 bills from page 3466.
# Fetched 50 bills from page 3467.
# Fetched 50 bills from page 3468.
# Fetched 50 bills from page 3469.
# Fetched 50 bills from page 3470.
# Fetched 50 bills from page 3471.
# Fetched 50 bills from page 3472.
# Fetched 50 bills from page 3473.
# Fetched 50 bills from page 3474.
# Fetched 50 bills from page 3475.
# Fetched 50 bills from page 3476.
# Fetched 50 bills from page 3477.
# Fetched 50 bills from page 3478.
# Fetched 50 bills from page 3479.
# Fetched 50 bills from page 3480.
# Fetched 50 bills from page 3481.
# Fetched 50 bills from page 3482.
# Fetched 50 bills from page 3483.
# Fetched 50 bills from page 3484.
# Fetched 50 bills from page 3485.
# Fetched 50 bills from page 3486.
# Fetched 50 bills from page 3487.
# Fetched 50 bills from page 3488.
# Fetched 50 bills from page 3489.
# Fetched 50 bills from page 3490.
# Fetched 50 bills from page 3491.
# Fetched 50 bills from page 3492.
# Fetched 50 bills from page 3493.
# Fetched 50 bills from page 3494.
# Fetched 50 bills from page 3495.
# Fetched 50 bills from page 3496.
# Fetched 50 bills from page 3497.
# Fetched 50 bills from page 3498.
# Fetched 50 bills from page 3499.
# Fetched 50 bills from page 3500.
# Fetched 50 bills from page 3501.
# Fetched 50 bills from page 3502.
# Fetched 50 bills from page 3503.
# Fetched 50 bills from page 3504.
# Fetched 50 bills from page 3505.
# Fetched 50 bills from page 3506.
# Fetched 50 bills from page 3507.
# Fetched 50 bills from page 3508.
# Fetched 50 bills from page 3509.
# Fetched 50 bills from page 3510.
# Fetched 50 bills from page 3511.
# Fetched 50 bills from page 3512.
# Fetched 50 bills from page 3513.
# Fetched 50 bills from page 3514.
# Fetched 50 bills from page 3515.
# Fetched 50 bills from page 3516.
# Fetched 50 bills from page 3517.
# Fetched 50 bills from page 3518.
# Fetched 50 bills from page 3519.
# Fetched 50 bills from page 3520.
# Fetched 50 bills from page 3521.
# Fetched 50 bills from page 3522.
# Fetched 50 bills from page 3523.
# Fetched 50 bills from page 3524.
# Fetched 50 bills from page 3525.
# Fetched 50 bills from page 3526.
# Fetched 50 bills from page 3527.
# Fetched 50 bills from page 3528.
# Fetched 50 bills from page 3529.
# Fetched 50 bills from page 3530.
# Fetched 50 bills from page 3531.
# Fetched 50 bills from page 3532.
# Fetched 50 bills from page 3533.
# Fetched 50 bills from page 3534.
# Fetched 50 bills from page 3535.
# Fetched 50 bills from page 3536.
# Fetched 50 bills from page 3537.
# Fetched 50 bills from page 3538.
# Fetched 50 bills from page 3539.
# Fetched 50 bills from page 3540.
# Fetched 50 bills from page 3541.
# Fetched 50 bills from page 3542.
# Fetched 50 bills from page 3543.
# Fetched 50 bills from page 3544.
# Fetched 50 bills from page 3545.
# Fetched 50 bills from page 3546.
# Fetched 50 bills from page 3547.
# Fetched 50 bills from page 3548.
# Fetched 50 bills from page 3549.
# Fetched 50 bills from page 3550.
# Fetched 50 bills from page 3551.
# Fetched 50 bills from page 3552.
# Fetched 50 bills from page 3553.
# Fetched 50 bills from page 3554.
# Fetched 50 bills from page 3555.
# Fetched 50 bills from page 3556.
# Fetched 50 bills from page 3557.
# Fetched 50 bills from page 3558.
# Fetched 50 bills from page 3559.
# Fetched 50 bills from page 3560.
# Fetched 50 bills from page 3561.
# Fetched 50 bills from page 3562.
# Fetched 50 bills from page 3563.
# Fetched 50 bills from page 3564.
# Fetched 50 bills from page 3565.
# Fetched 50 bills from page 3566.
# Fetched 50 bills from page 3567.
# Fetched 50 bills from page 3568.
# Fetched 50 bills from page 3569.
# Fetched 50 bills from page 3570.
# Fetched 50 bills from page 3571.
# Fetched 50 bills from page 3572.
# Fetched 50 bills from page 3573.
# Fetched 50 bills from page 3574.
# Fetched 50 bills from page 3575.
# Fetched 50 bills from page 3576.
# Fetched 50 bills from page 3577.
# Fetched 50 bills from page 3578.
# Fetched 50 bills from page 3579.
# Fetched 50 bills from page 3580.
# Fetched 50 bills from page 3581.
# Fetched 50 bills from page 3582.
# Fetched 50 bills from page 3583.
# Fetched 50 bills from page 3584.
# Fetched 50 bills from page 3585.
# Fetched 50 bills from page 3586.
# Fetched 50 bills from page 3587.
# Fetched 50 bills from page 3588.
# Fetched 50 bills from page 3589.
# Fetched 50 bills from page 3590.
# Fetched 50 bills from page 3591.
# Fetched 50 bills from page 3592.
# Fetched 50 bills from page 3593.
# Fetched 50 bills from page 3594.
# Fetched 50 bills from page 3595.
# Fetched 50 bills from page 3596.
# Fetched 50 bills from page 3597.
# Fetched 50 bills from page 3598.
# Fetched 50 bills from page 3599.
# Fetched 50 bills from page 3600.
# Fetched 50 bills from page 3601.
# Fetched 50 bills from page 3602.
# Fetched 50 bills from page 3603.
# Fetched 50 bills from page 3604.
# Fetched 50 bills from page 3605.
# Fetched 50 bills from page 3606.
# Fetched 50 bills from page 3607.
# Fetched 50 bills from page 3608.
# Fetched 50 bills from page 3609.
# Fetched 50 bills from page 3610.
# Fetched 50 bills from page 3611.
# Fetched 50 bills from page 3612.
# Fetched 50 bills from page 3613.
# Fetched 50 bills from page 3614.
# Fetched 50 bills from page 3615.
# Fetched 50 bills from page 3616.
# Fetched 50 bills from page 3617.
# Fetched 50 bills from page 3618.
# Fetched 50 bills from page 3619.
# Fetched 50 bills from page 3620.
# Fetched 50 bills from page 3621.
# Fetched 50 bills from page 3622.
# Fetched 50 bills from page 3623.
# Fetched 50 bills from page 3624.
# Fetched 50 bills from page 3625.
# Fetched 50 bills from page 3626.
# Fetched 50 bills from page 3627.
# Fetched 50 bills from page 3628.
# Fetched 50 bills from page 3629.
# Fetched 50 bills from page 3630.
# Fetched 50 bills from page 3631.
# Fetched 50 bills from page 3632.
# Fetched 50 bills from page 3633.
# Fetched 50 bills from page 3634.
# Fetched 50 bills from page 3635.
# Fetched 50 bills from page 3636.
# Fetched 50 bills from page 3637.
# Fetched 50 bills from page 3638.
# Fetched 50 bills from page 3639.
# Fetched 50 bills from page 3640.
# Fetched 50 bills from page 3641.
# Fetched 50 bills from page 3642.
# Fetched 50 bills from page 3643.
# Fetched 50 bills from page 3644.
# Fetched 50 bills from page 3645.
# Fetched 50 bills from page 3646.
# Fetched 50 bills from page 3647.
# Fetched 50 bills from page 3648.
# Fetched 50 bills from page 3649.
# Fetched 50 bills from page 3650.
# Fetched 50 bills from page 3651.
# Fetched 50 bills from page 3652.
# Fetched 50 bills from page 3653.
# Fetched 50 bills from page 3654.
# Fetched 50 bills from page 3655.
# Fetched 50 bills from page 3656.
# Fetched 50 bills from page 3657.
# Fetched 50 bills from page 3658.
# Fetched 50 bills from page 3659.
# Fetched 50 bills from page 3660.
# Fetched 50 bills from page 3661.
# Fetched 50 bills from page 3662.
# Fetched 50 bills from page 3663.
# Fetched 50 bills from page 3664.
# Fetched 50 bills from page 3665.
# Fetched 50 bills from page 3666.
# Fetched 50 bills from page 3667.
# Fetched 50 bills from page 3668.
# Fetched 50 bills from page 3669.
# Fetched 50 bills from page 3670.
# Fetched 50 bills from page 3671.
# Fetched 50 bills from page 3672.
# Fetched 50 bills from page 3673.
# Fetched 50 bills from page 3674.
# Fetched 50 bills from page 3675.
# Fetched 50 bills from page 3676.
# Fetched 50 bills from page 3677.
# Fetched 50 bills from page 3678.
# Fetched 50 bills from page 3679.
# Fetched 50 bills from page 3680.
# Fetched 50 bills from page 3681.
# Fetched 50 bills from page 3682.
# Fetched 50 bills from page 3683.
# Fetched 50 bills from page 3684.
# Fetched 50 bills from page 3685.
# Fetched 50 bills from page 3686.
# Fetched 50 bills from page 3687.
# Fetched 50 bills from page 3688.
# Fetched 50 bills from page 3689.
# Fetched 50 bills from page 3690.
# Fetched 50 bills from page 3691.
# Fetched 50 bills from page 3692.
# Fetched 50 bills from page 3693.
# Fetched 50 bills from page 3694.
# Fetched 50 bills from page 3695.
# Fetched 50 bills from page 3696.
# Fetched 50 bills from page 3697.
# Fetched 50 bills from page 3698.
# Fetched 50 bills from page 3699.
# Fetched 50 bills from page 3700.
# Fetched 50 bills from page 3701.
# Fetched 50 bills from page 3702.
# Fetched 50 bills from page 3703.
# Fetched 50 bills from page 3704.
# Fetched 50 bills from page 3705.
# Fetched 50 bills from page 3706.
# Fetched 50 bills from page 3707.
# Fetched 50 bills from page 3708.
# Fetched 50 bills from page 3709.
# Fetched 50 bills from page 3710.
# Fetched 50 bills from page 3711.
# Fetched 50 bills from page 3712.
# Fetched 50 bills from page 3713.
# Fetched 50 bills from page 3714.
# Fetched 50 bills from page 3715.
# Fetched 50 bills from page 3716.
# Fetched 50 bills from page 3717.
# Fetched 50 bills from page 3718.
# Fetched 50 bills from page 3719.
# Fetched 50 bills from page 3720.
# Fetched 50 bills from page 3721.
# Fetched 50 bills from page 3722.
# Fetched 50 bills from page 3723.
# Fetched 50 bills from page 3724.
# Fetched 50 bills from page 3725.
# Fetched 50 bills from page 3726.
# Fetched 50 bills from page 3727.
# Fetched 50 bills from page 3728.
# Fetched 50 bills from page 3729.
# Fetched 50 bills from page 3730.
# Fetched 50 bills from page 3731.
# Fetched 50 bills from page 3732.
# Fetched 50 bills from page 3733.
# Fetched 50 bills from page 3734.
# Fetched 50 bills from page 3735.
# Fetched 50 bills from page 3736.
# Fetched 50 bills from page 3737.
# Fetched 50 bills from page 3738.
# Fetched 50 bills from page 3739.
# Fetched 50 bills from page 3740.
# Fetched 50 bills from page 3741.
# Fetched 50 bills from page 3742.
# Fetched 50 bills from page 3743.
# Fetched 50 bills from page 3744.
# Fetched 50 bills from page 3745.
# Fetched 50 bills from page 3746.
# Fetched 50 bills from page 3747.
# Fetched 50 bills from page 3748.
# Fetched 50 bills from page 3749.
# Fetched 50 bills from page 3750.
# Fetched 50 bills from page 3751.
# Fetched 50 bills from page 3752.
# Fetched 50 bills from page 3753.
# Fetched 50 bills from page 3754.
# Fetched 50 bills from page 3755.
# Fetched 50 bills from page 3756.
# Fetched 50 bills from page 3757.
# Fetched 50 bills from page 3758.
# Fetched 50 bills from page 3759.
# Fetched 50 bills from page 3760.
# Fetched 50 bills from page 3761.
# Fetched 50 bills from page 3762.
# Fetched 50 bills from page 3763.
# Fetched 50 bills from page 3764.
# Fetched 50 bills from page 3765.
# Fetched 50 bills from page 3766.
# Fetched 50 bills from page 3767.
# Fetched 50 bills from page 3768.
# Fetched 50 bills from page 3769.
# Fetched 50 bills from page 3770.
# Fetched 50 bills from page 3771.
# Fetched 50 bills from page 3772.
# Fetched 50 bills from page 3773.
# Fetched 50 bills from page 3774.
# Fetched 50 bills from page 3775.
# Fetched 50 bills from page 3776.
# Fetched 50 bills from page 3777.
# Fetched 50 bills from page 3778.
# Fetched 50 bills from page 3779.
# Fetched 50 bills from page 3780.
# Fetched 50 bills from page 3781.
# Fetched 50 bills from page 3782.
# Fetched 50 bills from page 3783.
# Fetched 50 bills from page 3784.
# Fetched 50 bills from page 3785.
# Fetched 50 bills from page 3786.
# Fetched 50 bills from page 3787.
# Fetched 50 bills from page 3788.
# Fetched 50 bills from page 3789.
# Fetched 50 bills from page 3790.
# Fetched 50 bills from page 3791.
# Fetched 50 bills from page 3792.
# Fetched 50 bills from page 3793.
# Fetched 50 bills from page 3794.
# Fetched 50 bills from page 3795.
# Fetched 50 bills from page 3796.
# Fetched 50 bills from page 3797.
# Fetched 50 bills from page 3798.
# Fetched 50 bills from page 3799.
# Fetched 50 bills from page 3800.
# Fetched 50 bills from page 3801.
# Fetched 50 bills from page 3802.
# Fetched 50 bills from page 3803.
# Fetched 50 bills from page 3804.
# Fetched 50 bills from page 3805.
# Fetched 50 bills from page 3806.
# Fetched 50 bills from page 3807.
# Fetched 50 bills from page 3808.
